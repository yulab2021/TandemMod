# %%
import os
import glob

# Directory to search for *.fast5 files
directory = 'guppy_single'

# Recursive glob search for *.fast5 files
fast5_files = glob.glob(os.path.join(directory, '**/*.fast5'), recursive=True)


fast5_files
# Out:
# ['guppy_single/0/271fe610-8b99-4b0e-b2a8-1d78755f7dc5.fast5',
#  'guppy_single/0/2c90b8a2-5727-4170-bb57-27fe0b3e36a4.fast5',
#  'guppy_single/0/27f1d03c-3b3a-4812-a1f9-5a5d7b3751f1.fast5',
#  'guppy_single/0/27d75f85-a581-492a-8119-6c34ae915316.fast5',
#  'guppy_single/0/06fd48cd-4527-4032-b51a-0a92443025bb.fast5',
#  'guppy_single/0/058c4f1c-29bc-4c23-b0e0-02953b011425.fast5',
#  'guppy_single/0/0b8898ca-a2cc-4687-a53a-15fc159ceb3b.fast5',
#  'guppy_single/0/26437f76-ac3e-4431-a08c-28bd6eb22d35.fast5',
#  'guppy_single/0/028d485d-5964-4eed-a249-274c97c71e9b.fast5',
#  'guppy_single/0/0c192d16-ab39-466c-8ed5-1a706942859a.fast5',
#  'guppy_single/0/2c69107a-34be-4f6f-90d9-a79281f26ef8.fast5',
#  'guppy_single/0/082bf237-f01f-4920-ad98-15dd327183bd.fast5',
#  'guppy_single/0/05a00f85-6539-4600-b920-8da47068af12.fast5',
#  'guppy_single/0/00f4ed9d-e90d-483e-801a-5664684e487e.fast5',
#  'guppy_single/0/04278436-7fb4-405d-a938-1752c041a338.fast5',
# ...
